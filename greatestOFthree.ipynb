# %%
var_a=int(input("enter first no."))
var_b=int(input("enter second no."))
var_c=int(input("enter third no."))
if var_a>=var_b and var_a>=var_c:
    #print("a is greatest")
     print("from  " +str(var_a)+ " , "+ str(var_b)+ " , " + str(var_c)+"   a is greatest")
elif var_b>=var_a and var_b>=var_c:
    print("b is greatest")
else:
    print("c is greatest")
# Out:
# enter first no. 10
# enter second no. 2
# enter third no. 1
# from  10 , 2 , 1   a is greatest

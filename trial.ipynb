# %%
print("Hello World")
# Out:
# Hello World

# %%
print("india","nepal")
# Out:
# india nepal

# %%
print("india",5,True)
# Out:
# india 5 True

# %%
print("india","nepal",sep='/')
# Out:
# india/nepal

# %%
print("india","nepal",sep='-')
# Out:
# india-nepal

# %%
print(True,1,sep='=')
# Out:
# True=1

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print({"name":"mishika","age" : 19, "gender":"female"})
# Out:
# {'name': 'mishika', 'age': 19, 'gender': 'female'}

# %%
print("enter you name")

name=input()
def greet():
  print("hello" " " +name)
greet()
# Out:
# enter you name
#  mishi
# hello mishi

# %%
def welcome(name="mishika"):
    print(f"welcome {name}")
welcome()
# Out:
# welcome mishika

# %%
print("enter value of a")
a=input()
print("enter value of b")
b=input()
print(int (a)+ int (b))
# Out:
# enter value of a
#  12
# enter value of b
#  12
# 24

# %%
def total(*numbers):
    return sum(numbers)
print(total(1,4,9))
# Out:
# 14

# %%
my_tuple=("mishika",20,5)
my_tuple
# Out:
# ('mishika', 20, 5)

# %%
my_tuple[-1]
# Out:
# 5

# %%
#tuple unpacking
numbers=(10,20,30,40)
a,b,c,d=numbers
a
b
c
d
# Out:
# 40

# %%
#for loop
num=(1,2,3)
for x in num:
    print(x)
# Out:
# 1
# 2
# 3

# %%
#combine 2 tuple concatenation
even=(2,4,6)
odd=(1,3,5)
print(even+odd)
# Out:
# (2, 4, 6, 1, 3, 5)

# %%
#deletion
even=(2,4,6)
odd=(1,3,5)
even
# Out:
# (2, 4, 6)

# %%
del(even)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 even
#
# NameError: name 'even' is not defined

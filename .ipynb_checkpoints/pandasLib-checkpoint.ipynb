# %%
#pandas-used for data analysis and data manipulation such as data cleaning or filtering

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
s=pd.Series([10,20,30]) #self indexed
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s=pd.Series([10,20,30], index=['a','b','c']) 
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
data={"Name":['mishika','mishi'],'age':[20,20]}
df=pd.DataFrame(data)
df
# Out:
#       Name  age
# 0  mishika   20
# 1    mishi   20

# %%
data={'name' :["a","b","c"],'age':[20,40,30],'score':[1,2,3]}
df=pd.DataFrame(data)
df
# Out:
#   name  age  score
# 0    a   20      1
# 1    b   40      2
# 2    c   30      3

# %%
#series=1d , dataframe=2d 
#dataframe from lit of dictionary

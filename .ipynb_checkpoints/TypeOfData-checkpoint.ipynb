# %%
a= "mishika"
b=20
c=5.3
d=False
e=2+3j

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>

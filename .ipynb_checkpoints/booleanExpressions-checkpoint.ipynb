# %%
#boolean datatype 
is_student = True
has_passed =  False
print ("is student and passed=",is_student and has_passed)
#and = both should be true
print("is student or passed=", is_student or has_passed)
print("not a student=", not is_student )
# Out:
# is student and passed= False
# is student or passed= True
# not a student= False

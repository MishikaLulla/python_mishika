# %%
#set = unordered unique iteams
my_set={1,1,2,3,4,5,5,5}
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
#add
my_set.add(6)

# %%
my_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set.add(5)
my_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#delete
my_set.remove(5)
my_set
# Out:
# {1, 2, 3, 4, 6}

# %%
#set operations
set1={1,2,3}
set2={3,4,5,6}
print("union=",set1|set2)
# Out:
# union= {1, 2, 3, 4, 5, 6}

# %%
print("intersection=",set1 & set2)
# Out:
# intersection= {3}

# %%
print("diff=",set1-set2)
# Out:
# diff= {1, 2}

# %%
print("diff=",set2-set1)
# Out:
# diff= {4, 5, 6}

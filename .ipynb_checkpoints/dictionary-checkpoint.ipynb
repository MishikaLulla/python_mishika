# %%
my_data={"name":"mishika","age":20}
my_data
# Out:
# {'name': 'mishika', 'age': 20}

# %%
print(my_data["age"])
# Out:
# 20

# %%
my_data["name"]
# Out:
# 'mishika'

# %%
#add data 
my_data["grade"]="A"

# %%
my_data
# Out:
# {'name': 'mishika', 'age': 20, 'grade': 'A'}

# %%
my_data["age"]="19"

# %%
my_data
# Out:
# {'name': 'mishika', 'age': '19', 'grade': 'A'}

# %%
#delete
del my_data["age"]
my_data
# Out:
# {'name': 'mishika', 'grade': 'A'}

# %%
#for loop
for key,value in my_data.items():
    print(key,value)
# Out:
# name mishika
# grade A

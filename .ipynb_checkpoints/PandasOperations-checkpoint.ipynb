# %%
import pandas as pd

# %%
data={"name":["a","b","c"], "age":[20,40,30],"score":[1,2,3]}
df=pd.DataFrame(data)
df
# Out:
#   name  age  score
# 0    a   20      1
# 1    b   40      2
# 2    c   30      3

# %%
df['name']
# Out:
# 0    a
# 1    b
# 2    c
# Name: name, dtype: object

# %%
df[['name','age']]
# Out:
#   name  age
# 0    a   20
# 1    b   40
# 2    c   30

# %%
df.iloc[0] #
# Out:
# name      a
# age      20
# score     1
# Name: 0, dtype: object

# %%
#slicing
df[0:2]
# Out:
#   name  age  score
# 0    a   20      1
# 1    b   40      2

# %%
df[0:1]
# Out:
#   name  age  score
# 0    a   20      1

# %%
df[df['age']>30]
# Out:
#   name  age  score
# 1    b   40      2

# %%
df[(df["age"]>30) & (df["score"]>1)]
# Out:
#   name  age  score
# 1    b   40      2

# %%
df.isnull()
# Out:
#     name    age  score
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False

# %%
df.dropna()
# Out:
#   name  age  score
# 0    a   20      1
# 1    b   40      2
# 2    c   30      3

# %%
df.rename(columns={'name':'Full name'},inplace=True)
df
# Out:
#   Full name  age  score
# 0         a   20      1
# 1         b   40      2
# 2         c   30      3

# %%
df.replace('a','mishika',inplace=True)
df
# Out:
#   Full name  age  score
# 0   mishika   20      1
# 1         b   40      2
# 2         c   30      3

# %%
df['age'].mean()
# Out:
# np.float64(30.0)

# %%
df['age'].sum()
# Out:
# np.int64(90)

# %%
df['age'].max()
# Out:
# 40

# %%
df['age'].min()
# Out:
# 20

# %%
df.sort_values(by='age') #default ascending
# Out:
#   Full name  age  score
# 0   mishika   20      1
# 2         c   30      3
# 1         b   40      2

# %%
df.sort_values(by='age',ascending=False)
# Out:
#   Full name  age  score
# 1         b   40      2
# 2         c   30      3
# 0   mishika   20      1

# %%
df.groupby('Full name')['age'].mean()
# Out:
# Full name
# b          40.0
# c          30.0
# mishika    20.0
# Name: age, dtype: float64

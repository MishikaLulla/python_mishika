# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while i<=5:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,10):
    if i==5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,6):
    if i==3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
for i in range(1,6):
    print(i)
else:
    print("loop completed")
# Out:
# 1
# 2
# 3
# 4
# 5
# loop completed

# %%
for i in range(1,20):
    if i%2==0:
     print(i)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
i=1
total=0
while i<=10:
   total+=i
   i+=1
print(total)
